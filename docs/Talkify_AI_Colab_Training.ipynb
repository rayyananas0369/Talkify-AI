# %% [markdown]
# # Talkify AI - Sign Language Training Notebook (Colab Version)
#
# This notebook allows you to train your models using Google's free GPUs.
#
# ## 1. Setup Environment

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Install dependencies
# !pip install mediapipe opencv-python tensorflow scikit-learn ultralytics

# %% [markdown]
# ## 2. Configuration

# %%
import os
import sys

# Adjust this path to where your Talkify_AI folder is located in Google Drive
PROJECT_PATH = '/content/drive/MyDrive/Talkify_AI'
sys.path.append(PROJECT_PATH)

DATA_PATH = os.path.join(PROJECT_PATH, 'backend/data/sign_language/alphabet/Gesture Image Data')
MODEL_SAVE_PATH = os.path.join(PROJECT_PATH, 'backend/models/sign_model_colab.h5')

print(f"Project path: {PROJECT_PATH}")

# %% [markdown]
# ## 3. Run Training Script
#
# Make sure you select **Runtime -> Change runtime type -> T4 GPU** before running this.

# %%
# %cd {PROJECT_PATH}
# !python backend/training/train_sign.py
